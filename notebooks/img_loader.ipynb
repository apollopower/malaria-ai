# %%
from PIL import Image
import urllib
import requests

# %%
url = 'http://s3-us-west-2.amazonaws.com/seround-avatars.com/4c07f769-28d1-4e8c-9f6f-24c412133fa8'

# %%
f = urllib.request.urlopen(url)

# %%
Image.open(f)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x1120B40B8>
